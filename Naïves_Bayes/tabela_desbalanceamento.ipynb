# %%
# Isso é considerado desbalanceamento?

# Depende do contexto:

# Proporção	Situação - DEPOIS DE FAZER ACURÁCIA
# 50% / 50%	Balanceado
# 60% / 40%	Leve desbalanceamento
# 75% / 25%	Moderado
# 90% / 10%	Forte
# 95% / 5%	Muito forte
