# %% [markdown]
# AMOSTRAGEM ALEATORIA SIMPLES

# %%
import pandas as pd
import numpy as np
import random

dataset = pd.read_csv('census.csv')
# display(dataset.head())
# display(dataset.shape)
# display(dataset.tail())
# display(dataset.sample(n= 100))#observação utiliza-se o random_state= 1 ou qualquer outro valor para repetir a mesma amostra.

amostra_aleatoria = dataset.sample(100)
#display(amostra_aleatoria)
display(amostra_aleatoria.shape)
# Out:
# (100, 15)

# %%
def funcao_aleatoria(dataset, n):
  return dataset.sample(n=100)

chamando_funcao = funcao_aleatoria(dataset, 100)
display(chamando_funcao)
# Out:
#        age workclass  final-weight      education  education-num  \
# 7293    34   Private        118941           11th              7
# 13687   36   Private        186212     Assoc-acdm             12
# 4121    49   Private         87928        HS-grad              9
# 10295   17   Private        228399           11th              7
# 11797   41   Private        204410        HS-grad              9
# ...    ...       ...           ...            ...            ...
# 18512   33   Private        174789   Some-college             10
# 10253   17         ?        210547           10th              6
# 30258   54   Private         35576   Some-college             10
# 20778   31   Private        113364     Assoc-acdm             12
# 17016   42   Private        367049        Masters             14
#
#             marital-status          occupation    relationship    race  \
# 7293         Never-married       Other-service   Not-in-family   White
# ...
